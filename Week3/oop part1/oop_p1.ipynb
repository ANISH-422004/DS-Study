# %% [markdown]
# ## Every thing in Python is an object, including functions, classes, and even modules. This means that they can be passed around and used as arguments, just like any other object (string, int, float, list, and so on).

# %%
l =[1,2,3]
l.upper()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[1], line 2
#       1 l =[1,2,3]
# ----> 2 l.upper()
#
# AttributeError: 'list' object has no attribute 'upper'

# %%
s = "hw"
print(type(s))
s.append()
# Out:
# <class 'str'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[6], line 3
#       1 s = "hw"
#       2 print(type(s))
# ----> 3 s.append()
#
# AttributeError: 'str' object has no attribute 'append'

# %%
def func():
    pass

func.attr = 42

print(func)
print(func.attr) # whattttt 
print(type(func))
# Out:
# <function func at 0x000001C589B62840>
# 42
# <class 'function'>

# %% [markdown]
# # What is OOP (Object Oriented Programming)?
# It is a programming paradigm that uses "objects" to design software. An object is an instance of a class, which is a blueprint for creating objects. OOP focuses on the concept of objects that contain data and methods to manipulate that data and other conpcepts like inheritance, polymorphism, encapsulation etc are also part of OOP.
#
#
#
# ## what problems does OOP solve?
# 1. generality to sepecificity : ex : linux os has many distributions like ubuntu, kali, fedora etc. All these distributions have some common features but also have some specific features. OOP allows us to create a general class (linux os) and then create specific classes (ubuntu, kali, fedora) that inherit from the general class.
# 2. code reusability : OOP allows us to create classes that can be reused in different parts of the code. This reduces code duplication and makes the code more maintainable. ex: we can create a class for a database connection and then use that class in different parts of the code instead of writing the same code again and again.
#
#
#
# ###### OOPS gives a programmer the power to create his own data types. These data types are known as classes and the objects created from these classes are known as instances. Classes can have attributes (data) and methods (functions) that operate on the data. This allows for better organization of code and makes it easier to understand and maintain.
#
# ## Principles of OOP
# 1. class : A class is a blueprint for creating objects. It defines the attributes and methods that an object of that class will have.
# 2. object : An object is an instance of a class. It contains data and methods that operate on that data.
# 3. inheritance : Inheritance is a mechanism that allows a class to inherit attributes and methods from another class. This allows for code reusability and helps to create a hierarchical relationship between classes.
# 4. polymorphism : Polymorphism is the ability of an object to take on many forms. It allows for methods to be used in different ways depending on the object that is calling them.
# 5. encapsulation : Encapsulation is the mechanism of hiding the internal details of an object and exposing only the necessary parts. This helps to protect the data and ensures that it is accessed in a controlled manner.
# 6. abstraction : Abstraction is the process of simplifying complex systems by breaking them down into smaller, more manageable parts. It allows for the creation of abstract classes and interfaces that define the behavior of objects without specifying the implementation details.

# %%
# Class is a blueprint for creating objects. An object is an instance of a class. Classes can have attributes (data) and methods (functions) that operate on the data.

# class  -   (Data or properties or attributes ) and (functions or methods)   

# Basic Class structure in Python

    # class ClassName:
        # attribute 1 = value
        # attribute 2 = value
        
        # def method1(self, parameters):
        #     # method body

# Syntax to create an object from a class
    # object_name = ClassName()


# Class naming : PascalCase : ex : HelloWorld , MyClass , Person , Animal , Car , BankAccount , Atm
class Atm : 
    def __init__(self , pin , name):   # constructor : special method inside a class which is called when an object is created from the class  
        self.balance = 0 # self is used to refer to the current instance of the class
        self.pin = pin
        self.name = name 
    
    def check_balance(self, pin):
        if pin == self.pin:
            return self.balance
        else:
            return "Invalid PIN"
        
    def deposit(self, amount): 
        self.balance += amount
        return self.balance
    
    def withdraw(self, amount, pin):
        if pin == self.pin:
            if amount <= self.balance:
                self.balance -= amount
                return self.balance
            else:
                return "Insufficient balance"
        else:
            return "Invalid PIN"
    
    def reset_pin(self , oldpin , newpin):
        if oldpin == self.pin:
            self.pin = newpin
            return "PIN successfully changed"
        else:
            return "Invalid old PIN"
        
    def __str__(self): 
        return f"Atm belonging to {self.name} with balance XXX "

# %%
anish_atm = Atm(1234 , "Anish")  # creating an object of class Atm

print(anish_atm)  # Atm belonging to Anish with balance XXX
print(anish_atm.check_balance(1234))  # 0
print(anish_atm.check_balance(0000))  # Invalid PIN
print(anish_atm.deposit(500))  # 500
print(anish_atm.withdraw(200, 1234))  # 300
print(anish_atm.withdraw(500, 1234))  # Insufficient balance
print(anish_atm.withdraw(100, 0000))  # Invalid PIN
print(anish_atm.reset_pin(0000, 5678))  # PIN successfully changed
print(anish_atm.reset_pin(1234, 5678))  # PIN successfully changed
# Out:
# Atm belonging to Anish with balance XXX
# 0
# Invalid PIN
# 500
# 300
# Insufficient balance
# Invalid PIN
# Invalid old PIN
# PIN successfully changed

# %% [markdown]
# ### There are  2 types of classes in Python:
# 1. Built-in classes : These are the classes that are provided by Python itself. Examples include int, float, str, list, dict, etc.
# 2. User-defined classes : These are the classes that are created by the user. Users can define their own classes to create custom data types and implement specific functionality.
#
#
# Methods are functions that are defined inside a class and are used to perform operations on the data contained in the class. Methods can be called on an object of the class to manipulate its data or perform specific actions.
#
# fro example :
#
#
# ```python
#  l = [1, 2, 3]
#     l.append(4)  # append is a method of the list class
#     len(l)  # len is a funciton that works on any iterable
# ```

# %% [markdown]
# Class Diagram for ATM example :
#
#
# ----------------------------------------------
# |          ATM Class                         |
# ----------------------------------------------
# | - name: str                                |
# | - balance: float                           |  -- > attributes
# | - pin: str                                 |
# ----------------------------------------------
# | + deposit(amount: float): None             |
# | + withdraw(amount: float, pin: str): str   |  -- > methods
# | + reset_pin(oldpin: str, newpin: str): str |
# ----------------------------------------------
# `+` == > public method
# `-` == > private attribute

# %% [markdown]
# ## Magic Methods :
#
# Magic methods / Dunder Method in Python are special methods that have double underscores (also known as dunder methods) at the beginning and end of their names. These methods are used to define the behavior of objects for built-in operations such as addition, subtraction, comparison, and string representation. Magic methods allow you to customize how your objects behave when they are used with built-in functions and operators.
#
# #### how to indentify magic methods? **MagicmethodName**
#
# examples of magic methods include:
#
# - `__init__`: This method is called when an object is created and is used to initialize the object's attributes.
#   Benefit ? : when we dont wanna give the control to user and want automatic initialization of attributes. -- set up some values when a program starts ex : createing DB connection, **setting up config values** and setting etc.
#
# ##### if Earth is class , humans are objects , then god will but whcih attribute in \__init_ ? its death time , birth time etc. so that humans dont have to set it manually.
#
# - `__str__`: This method is called when the `str()` function is used on an object and is used to define the string representation of the object and it is called when the `print()` function is used on the object ex : print(object123).
# - `__add__`: This method is called when the `+` operator is used on two objects and is used to define how the objects should be added together. Triggers when we do obj1 + obj2
# - ` __sub__`: This method is called when the `-` operator is used on two objects and is used to define how the objects should be subtracted. Triggers when we do obj1 - obj2
# - `__mul__`: This method is called when the `*` operator is used on two objects and is used to define how the objects should be multiplied. Triggers when we do obj1 * obj2
# - `__truedeiv__`: Thsi method is called when `/` operator is used on two objects and is used to define how the objects should be multiplied. Triggers when we do obj1 / obj2
#
# #### Golden Rule of OOPS is that "methods of a class only can be called by its objects"
#
# - so normally we call methods using objects of the class.
# - but a method of a class cant call another method of the same class directly not even inside the class and this problem is solved by using "self" keyword.
# - self is a reference to the current instance of the class and is used to access the attributes and methods of the class.

# %%
class Class1 : 
    def __init__(self , param1 , param2):
        print(id(self))  # prints the memory address of the object
        self.attr1 = param1
        self.attr2 = param2
        
obj1 = Class1("value1" , "value2")
# Out:
# 1947921838688

# %%
id(obj1)  # prints the memory address of obj1
# Out:
# 1947921838688

# %% [markdown]
# ##### See above both id are same ,  now if self becomes the obejct of that class then it can call other methods of the class using self.methodname() , form another method of the same class.

# %%
class Class2 : 
    def __init__(self , param1 , param2):
        self.attr1 = param1
        self.attr2 = param2
        
    def method1():
        print(self.attr1)

# %%
c2 = Class2("val1" , "val2")

# %%
c2.method1() # Error: method1() missing 1 required positional argument: 'self'

## hidden Syntax when we do obj.method() is   ---> Class.method(obj)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[24], line 1
# ----> 1 c2.method1()
#
# TypeError: Class2.method1() takes 0 positional arguments but 1 was given

# %% [markdown]
# ## hidden Syntax when we do obj.method() is   ---> Class.method(obj)
# ##### self is just a convention, we can use any other name but it is recommended to use self for better readability.

# %%
#### Creating Fraction Data Type with OOP

class Fraction: 
    """
        This is a Fraction class to represent fractions
        Attributes:
            numerator (int): The numerator of the fraction
            denominator (int): The denominator of the fraction
        Methods:
            __str__: Returns the string representation of the fraction
            
    """
    def __init__(self , numerator , denominator):
        self.numerator = numerator
        self.denominator = denominator
        
    def __str__(self):
        return f"{self.numerator}/{self.denominator}"
    
    def __add__(self, other):
        new_numerator = self.numerator * other.denominator + other.numerator * self.denominator
        new_denominator = self.denominator * other.denominator
        return Fraction(new_numerator, new_denominator)
    
    def __sub__(self, other):
        new_numerator = self.numerator * other.denominator - other.numerator * self.denominator
        new_denominator = self.denominator * other.denominator
        return Fraction(new_numerator, new_denominator)
    
    def __mul__(self, other):
        new_numerator = self.numerator * other.numerator
        new_denominator = self.denominator * other.denominator
        return Fraction(new_numerator, new_denominator)
    
    def __truediv__(self, other):
        new_numerator = self.numerator * other.denominator
        new_denominator = self.denominator * other.numerator
        return Fraction(new_numerator, new_denominator)

# %%
num = Fraction(3,4)
print(num)  # 3/4
# Out:
# 3/4

# %%
num2 = Fraction(5,8)
print(num2)  # 5/8
# Out:
# 5/8

# %%
num2 = num + num2  ## we need __add__
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 num2 = num + num2
#
# TypeError: unsupported operand type(s) for +: 'Fraaction' and 'Fraaction'

# %%
num2 = num + num2
print(num2)  # 47/32

fr1 = Fraction(2,3)
fr2 = Fraction(4,5)

fr3 = fr1 * fr2
print(fr3)  # 8/15
print(fr1 / fr2)  # 10/12
# Out:
# 7424/2048
# 8/15
# 10/12
