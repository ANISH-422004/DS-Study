# %% [markdown]
# - How indexing works in sets
# - Why dict key cant be mutable data types
# - Enumerate
# - destructor
# - dir/isinstance/issubclass
# - classmethod vs staticmethod
# - The diamond problem
# - What’s the meaning of single and double underscores in Python variable and method names
# - Magic Methods (repr vs str)
# - How can objects be stored in sets even though they are mutable

# %%
s = {21,34,11,56,39}
s 
#### - How indexing works in sets

## see the order is changed its beacause it also stored in array like structure and uses hashing to determine the index to store the value in that index 

## collision  : when two values are passed through hash function and they give same index
## in that case both values are stored in the same index using linked list or other data structure 
# probing : in this method when collision occurs we look for next empty index to store the value example linear probing , quadratic probing etc
# chaining : in this method when collision occurs we store both values in the same index using linked list or other data structure


## Dictionary are stored in from of key value pairs
## its uses the conept of hashing
## where fro each key it is passed through a hash function and we get a unique value
## that values (idx) is used to store the value in memory in a array like structure
## advantage of this is we can access the value in O(1) time complexity
# Out:
# {11, 21, 34, 39, 56}

# %%
# - Why dict key cant be mutable data types ## one word reason is key must be mutable if its not  then its index value will change and we need to repalce the value in new index which is very tidious that why python makers did not allowd it only 

d = {(1,2,3):'nitish'}
d
# Out:
# {(1, 2, 3): 'nitish'}

# %%
d = {[1,2,3]:'nitish'}
d
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-99-968dc6d378a3> in <module>
# ----> 1 d = {[1,2,3]:'nitish'}
#       2 d
#
# TypeError: unhashable type: 'list'

# %%
# enumerate
# The enumerate() method adds a counter to an iterable and returns it (the enumerate object).
def select_item_to_be_sorted(item , idx = 0) : 
    return item[idx]

L = [('nitish',45),('ankit',31),('ankita',40)]
print("initial list :",L)

print(sorted(L,key=lambda x:select_item_to_be_sorted(x,1),reverse=True))

## another way
print(sorted(L,key=lambda x:x[1],reverse=True))
# Out:
# initial list : [('nitish', 45), ('ankit', 31), ('ankita', 40)]
# [('nitish', 45), ('ankita', 40), ('ankit', 31)]
# [('nitish', 45), ('ankita', 40), ('ankit', 31)]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[16], line 15
#      12 print(sorted(L,key=lambda x:x[1],reverse=True))
#      14 ## without lambda function
# ---> 15 print(sorted(L , key = select_item_to_be_sorted(idx = 1) , reverse=True))
#
# TypeError: select_item_to_be_sorted() missing 1 required positional argument: 'item'

# %%
L = [15,21,13,13]
sorted(list(enumerate(L)),reverse=True)
# Out:
# [(3, 13), (2, 13), (1, 21), (0, 15)]

# %%
# destructor
class Example:

  def __init__(self):
    print('constructor called')

  # destructor : called when all instance of that class is deleted : config relateed codes
  def __del__(self):
    print('destructor called')

obj = Example()
a = obj
del a
# Out:
# constructor called

# %%
del obj
# Out:
# destructor called

# %%
# dir : it gives us the list of attributes and methods of an object (default and custom both)

class Test:
    def __init__(self):
        self.foo = 11
        self._bar = 23
        self.__baz = 23

    def greet(self):
      print('hello')

t = Test()
print(dir(t)) # This gives us a list with the object’s attributes
# Out:
# ['_Test__baz', '__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_bar', 'foo', 'greet']

# %% [markdown]
# #### Name Mangling in Python :
# - Name mangling is a mechanism in Python that alters the name of a class attribute to make it harder to create subclasses that accidentally override the private attributes and methods of their superclasses.
#
# ex :
#
# ```python
# class MyClass:
#     def __init__(self):
#         self.__private_var = 42  # This variable is name-mangled -- > _MyClass__private_var
# obj = MyClass()
# print(obj.__private_var)  # This will raise an AttributeError
# ```

# %%
# issubclass
class A:
  def __init__(self):
    pass

class B(A):
  pass

issubclass(B,A)
# Out:
# True

# %% [markdown]
# ### classmethod
# - A class method is a method that is bound to the class and not the object of the class.
# - They have the access to the state of the class as it takes a class parameter that points to the class and not the object instance.
# - It can modify a class state that would apply across all the instances of the class. For example, it can modify a class variable that will be applicable to all the instances.

# %% [markdown]
# ### staticmethod
# A static method does not receive an implicit first argument. A static method is also a method that is bound to the class and not the object of the class. This method can’t access or modify the class state. It is present in a class because it makes sense for the method to be present in class.

# %%
class A:

  def normal_m(self):
    print('normal method')

  @staticmethod
  def static_m():
    print('static method')

  @classmethod
  def class_m(cls):
    print('class method')

# %%
a = A()

# normal -> object -> callable
a.normal_m()
# class -> object -> callable
a.class_m()
# static -> object -> not callable
a.static_m()
# Out:
# normal method
# class method
# static method

# %%
# static -> class -> callable
A.static_m()
# class method -> class -> callable
A.class_m()
# normal -> class -> not callable
A.normal_m()
# Out:
# static method
# class method
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-94-088d25a52aaf> in <module>
#       4 A.class_m()
#       5 # normal -> class -> not callable
# ----> 6 A.normal_m()
#
# TypeError: normal_m() missing 1 required positional argument: 'self'

# %%
# Alternate syntax
A.normal_m(a)

# %% [markdown]
# ### Class method vs Static Method<br>
# The difference between the Class method and the static method is:
#
# - A class method takes cls as the first parameter while a static method needs no specific parameters.
# - A class method can access or modify the class state while a static method can’t access or modify it.
# - In general, static methods know nothing about the class state. They are utility-type methods that take some parameters and work upon those parameters. On the other hand class methods must have class as a parameter.
# - We use @classmethod decorator in python to create a class method and we use @staticmethod decorator to create a static method in python.

# %% [markdown]
# ### When to use the class or static method?
# - We generally use the class method to create factory methods. Factory methods return class objects ( similar to a constructor ) for different use cases.
# - We generally use static methods to create utility functions.

# %%
# The diamond problem
class Class1:
    def m(self):
        print("In Class1")

class Class2(Class1):
    def m(self):
        print("In Class2")

class Class3(Class1):
    def m(self):
        print("In Class3")

class Class4(Class3, Class2):
    pass

obj = Class4()
obj.m()
# MRO (Method Resolution Order)
# Out:
# In Class3

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
# Double and single score

# %%
# repr and other magic/dunder methods

a = 'hello'

print(str(a))
print(repr(a))
# Out:
# hello
# 'hello'

# %%
import datetime

a = datetime.datetime.now()
b = str(a)

print(str(a))
print(str(b))

print(repr(a))
print(repr(b))
# Out:
# 2022-11-26 15:46:52.007475
# 2022-11-26 15:46:52.007475
# datetime.datetime(2022, 11, 26, 15, 46, 52, 7475)
# '2022-11-26 15:46:52.007475'

# %% [markdown]
# ### In summary
#
# - str is for users -> meant to be more readable
# - repr is for developers for debugging - > for being unambigous

# %%
# how objects are stored even though they are mutable
# https://stackoverflow.com/questions/31340756/python-why-can-i-put-mutable-object-in-a-dict-or-set
class A:

  def __init__(self):
    print('constructor')

  def hello(self):
    print('hello')

a = A()
a.hello()
s = {a}
print(s)
dir(a)
# Out:
# constructor
# hello
# {<__main__.A object at 0x7f4f5f3fd510>}
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'hello']

# %%
class A:

  def __init__(self):
    print('constructor')

  def __eq__(self):
    pass

  def __hash__(self):
    return 1

  def hello(self):
    print('hello')

a = A()
a.hello()
s = {a}
print(s)

dir(a)
# Out:
# constructor
# hello
# {<__main__.A object at 0x7f4f5f369290>}
# ['__class__',
#  '__delattr__',
#  '__dict__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__le__',
#  '__lt__',
#  '__module__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  '__weakref__',
#  'hello']

# %%
class A:

  def __init__(self):
    self._var = 10

a = A()
a._var
# Out:
# 10

# %%
s = {[1,2]}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-125-abf442ad56c0> in <module>
# ----> 1 s = {[1,2]}
#
# TypeError: unhashable type: 'list'

# %%
L = [1,2,3]
s = {L}
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-129-fc3c139945bb> in <module>
#       1 L = [1,2,3]
# ----> 2 s = {L}
#
# TypeError: unhashable type: 'list'

# %%
print(L.__hash__)
# Out:
# None

# %%
hash(1)
# Out:
# 1

# %%
hash('hello')
# Out:
# 4306082800328210013

# %%
hash((1,2,3,))
# Out:
# 2528502973977326415

# %%
hash([1,2,3])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-141-35e31e935e9e> in <module>
# ----> 1 hash([1,2,3])
#
# TypeError: unhashable type: 'list'
